# %%
# Note: Used the below-mentioned video in conjunction with DataCamp notes.

# Learn Pytest in 60 Minutes : Python Unit Testing Framework
# https://www.youtube.com/watch?v=bbp_849-RZ4

# %% [markdown]
# ![Recommendation.PNG](attachment:Recommendation.PNG)

# %% [markdown]
# ![Float%20values-2.PNG](attachment:Float%20values-2.PNG)

# %%
# Use pytest.approx(). This ensures that the digits far on the right are 
# ignored and we can compare floats safely.

# %% [markdown]
# ![Context%20Manager.PNG](attachment:Context%20Manager.PNG)

# %% [markdown]
# ![Testing%20the%20error%20message.PNG](attachment:Testing%20the%20error%20message.PNG)

# %%
# pytest test_math_func_2.py -v -m number
# pytest -v -x (It stops as soon as the first failure occurs)
# pytest -v --maxfail=2
# pytest -v -s (test passes with the customprint system)
# pytest -v --capture=no (test passes with the customprint system)
# pytest -v -q(Only important information gets printed)

# %% [markdown]
# ![test_math_func_2.PNG](attachment:test_math_func_2.PNG)

# %% [markdown]
# ![Advice.PNG](attachment:Advice.PNG)

# %% [markdown]
# ![TDD.PNG](attachment:TDD.PNG)

# %% [markdown]
# ![TDD%20test%20steps.PNG](attachment:TDD%20test%20steps.PNG)

# %% [markdown]
# ![xfail,%20skipif.PNG](attachment:xfail,%20skipif.PNG)
