# %%
# https://realpython.com/python-testing/

# %% [markdown]
# ![Life%20cycle%20of%20a%20function.PNG](attachment:Life%20cycle%20of%20a%20function.PNG)

# %% [markdown]
# ![Manual%20vs%20Unit%20testing.PNG](attachment:Manual%20vs%20Unit%20testing.PNG)

# %%
# Steps for the Unit Testing

# 1) In our case, math_func.py file is created
# 2) Whereas, test_math_func.py is created to test the functions in 1)

# %% [markdown]
# ![math_func.PNG](attachment:math_func.PNG)

# %% [markdown]
# ![test_math_func.PNG](attachment:test_math_func.PNG)

# %%
# Go to terminal to test the above-mentioned functions.

# 1) pyment test_math_func.py
# 2) pyment test_math_func.py -v
# 3) pyment test_math_func.py -v -k "add"

# %% [markdown]
# ![Unit%20Tests%20steps.PNG](attachment:Unit%20Tests%20steps.PNG)

# %% [markdown]
# ![Multiple%20Tests.PNG](attachment:Multiple%20Tests.PNG)

# %% [markdown]
# ![Reduced%20Downtime.PNG](attachment:Reduced%20Downtime.PNG)

# %% [markdown]
# ![End%20to%20end%20tests.PNG](attachment:End%20to%20end%20tests.PNG)
