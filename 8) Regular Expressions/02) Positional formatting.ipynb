# %%
# String Formatting

custom_string = "String formatting"
print(f"{custom_string} is a powerful technique")
# Out:
# String formatting is a powerful technique

# %%
# Methods for formatting
# i) Positional formatting
# ii) Formatted string literals
# iii) Template Method

my_string = "{} rely on {} datasets"
method = "Supervised algorithms"
condition = "labeled"

print(my_string.format(method, condition))
# Out:
# Supervised algorithms rely on labeled datasets

# %%
# Reordering Values

print("{1} rely on {0} datasets".format("labeled","Supervised algorithms"))
# Out:
# Supervised algorithms rely on labeled datasets

# %%
# Named placeholders

tool="Unsupervised algorithms"
goal="patterns"
print("{tool} try to find {goal} in the dataset")
# Out:
# {tool} try to find {goal} in the dataset

# %%
tool="Unsupervised algorithms"
goal="patterns"

print("{title} try to find {aim} in the dataset".format(title=tool, aim=goal))
# Out:
# Unsupervised algorithms try to find patterns in the dataset

# %%
# Named placeholder

my_methods = {"tool" : "Unsupervised algorithms", "goal": "patterns"}
print('{data[tool]} try to find {data[goal]} in the dataset'.format(data=my_methods))
# Out:
# Unsupervised algorithms try to find patterns in the dataset

# %%
# Format specifier

# {index: specifier}

print("Only {0:f}% of the {1} produced worldwide is {2}!".format(0.5155675, "data", "analyzed"))
# Out:
# Only 0.515567% of the data produced worldwide is analyzed!

# %%
# Formatting datetime

from datetime import datetime
print(datetime.now())
# Out:
# 2021-11-25 18:09:52.898769

# %%
print("Today's date is {:%Y-%m-%d %H:%M}".format(datetime.now()))
# Out:
# Today's date is 2021-11-25 18:11

# %%
# Formatted string literal

way = "code"
method = "learning Python faster"
print(f"Practicing how to {way} is the best method for {method}")
# Out:
# Practicing how to code is the best method for learning Python faster

# %% [markdown]
# ![Type%20Conversion,%20Format%20Specifiers.PNG](attachment:Type%20Conversion,%20Format%20Specifiers.PNG)

# %%
name = 'Python'
print(f"Python is called {name!r} due to a comedy series")
# Out:
# Python is called 'Python' due to a comedy series

# %%
# Format specifiers

number = 90.415235
print(f"In the last 2 years, {number:.2f}% of the data is produced worldwide!")
# Out:
# In the last 2 years, 90.42% of the data is produced worldwide!

# %%
# Format specifiers

from datetime import datetime
my_today = datetime.now()

print(f"Today's date is {my_today:%B %d, %Y}")
# Out:
# Today's date is November 25, 2021

# %%
# Index Lookups

family = {"name": "Ian", "siblings": "Peter"}
print("Is your dad called {family[name]}?".format(family=family))
# Out:
# Is your dad called Ian?

# %%
# Use quote for Index lookup
print(f"Is your dad called {family['name']}")
# Out:
# Is your dad called Ian

# %%
# Escape sequences
# If the string contains quotes as well, one of the ways to escape the 
# error raised is to add a backslash before the quotes.

print("My dad is called \"John\"")
# Out:
# My dad is called "John"

# %%
# Note: Backslashes are not allowed in f-strings

# %%
# Inline operations
# One of the biggest advantages of f-strings is that they allow us to 
# perform inline operations.

my_number = 4
my_multiplier = 7
print(f'{my_number} multiplied by {my_multiplier} is {my_number * my_multiplier}')
# Out:
# 4 multiplied by 7 is 28

# %%
# Calling Functions
def func(a,b):
        return a + b

print(f"If you sum up 10 and 20 the result is {func(10,20)}")
# Out:
# If you sum up 10 and 20 the result is 30

# %% [markdown]
# ![Template%20Strings,%20Safe%20Substitution.PNG](attachment:Template%20Strings,%20Safe%20Substitution.PNG)

# %%
from string import Template
my_string = Template('Data science has been called $identifier')
my_string.substitute(identifier="sexiest job of the 21st century")
# Out:
# 'Data science has been called sexiest job of the 21st century'

# %%
# Substitution

from string import Template
job = "Data science"
name = "sexiest job of the 21st century"
my_string = Template("$title has been called the $description")
my_string.substitute(title=job, description=name)
# Out:
# 'Data science has been called the sexiest job of the 21st century'

# %%
# Substitution
# Use ${identifier} when valid characters follow identifier

my_string = Template('I find Python very ${noun}ing but my sister has lost $noun')
my_string.substitute(noun="interest")
# Out:
# 'I find Python very interesting but my sister has lost interest'

# %%
# Use $$ to escape the dollar sign
# you will need to escape this character by adding an extra dollar sign. 

my_string = Template('I paid for the Python course only $$ $price, amazing!'
)
my_string.substitute(price="12.50")
# Out:
# 'I paid for the Python course only $ 12.50, amazing!'

# %% [markdown]
# ![Subsitution%20&%20Safe%20Substitution.PNG](attachment:Subsitution%20&%20Safe%20Substitution.PNG)

# %% [markdown]
# ![Which%20to%20use..PNG](attachment:Which%20to%20use..PNG)
