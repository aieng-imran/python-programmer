# %% [markdown]
# # Grouping & Capturing
#
# 1) Capturing Groups
#
# 2) Alternation and noncapturing groups (Pipe, Alternation, ...)
#
# 3) Backreferences a pattern
#
# 4) Lookaround an expression

# %% [markdown]
# ![Capturing%20Groups.PNG](attachment:Capturing%20Groups.PNG)

# %%
import re

text = '''
Clary has 2 friends. Susan has 3 brothers. Ian has 4 girlfriends
'''

re.findall(r'([A-Za-z]+)\s\w+\s(\d+)\s(\w+)', text)
# Out:
# [('Clary', '2', 'friends'),
#  ('Susan', '3', 'brothers'),
#  ('Ian', '4', 'girlfriends')]

# %%
names[0][0]
# Out:
# 'Clary'

# %%
# Capture a repeated group (\d+) vs. repeat a capturing group (\d)+

my_string = "My lucky numbers are 8755 and 33"
re.findall(r"(\d)+", my_string)
# Out:
# ['5', '3']

# %%
re.findall(r"(\d+)", my_string)
# Out:
# ['8755', '33']

# %%
# Alternation and noncapturing groups

# Pipe |

my_string = "I want to have a pet. But I don't know if I want a cat, a dog or a bird."
re.findall(r"cat|dog|bird", my_string)
# Out:
# ['cat', 'dog', 'bird']

# %% [markdown]
# ![Quantifiers.PNG](attachment:Quantifiers.PNG)

# %%
# Non-capturing group

# %% [markdown]
# ![Non-capturing%20group.PNG](attachment:Non-capturing%20group.PNG)

# %%
# Backreferences

# %%
# Numbered groups

text = "Python 3.0 was released on 12-03-2008."

information = re.search('(\d{1,2})-(\d{2})-(\d{4})', text)
information.group(3)
# Out:
# '2008'

# %%
# Looking around

# Look-around will look for what is behind or ahead of a pattern. 
# Imagine that we have the following string.
