# %% [markdown]
# # Regex Expression
#
# 1) Basic syntax
#
# 2) Normal characters
#
# 3) Metacharacters
#
# 4) Greedy and non-greedy quanties

# %%
# https://pythex.org/

# %% [markdown]
# ![Regex-%20Cheatsheet.PNG](attachment:Regex-%20Cheatsheet.PNG)

# %% [markdown]
# ![Special%20Sequences.PNG](attachment:Special%20Sequences.PNG)

# %%
# Python RegEx | Python Regular Expressions Tutorial
# https://www.youtube.com/watch?v=zN8rwVXwRUE

import re

Nameage = '''
Ian is 31 and Farwa is 27
Tom is 25 and Sara is 23
'''

ages = re.findall(r'\d{1,3}', Nameage)
names = re.findall(r'[A-Z][a-z]*', Nameage)

ageDict = {}

x = 0

for eachname in names:
    ageDict[eachname] = ages[x]
    x += 1

print(ageDict)
# Out:
# {'Ian': '31', 'Farwa': '27', 'Tom': '25', 'Sara': '23'}

# %%
sentiment = """
@robot9! @robot4& I have a good feeling that the show isgoing to be 
amazing @robot9$ @robot7%"
"""

import re

regex= r"@robot\d\W"
print(re.findall(regex, sentiment))
# Out:
# ['@robot9!', '@robot4&', '@robot9$', '@robot7%']

# %%
import re

food = "hat rat mat pat"

regex = re.compile("[r]at")

food = regex.sub("food", food)

print(food)
# Out:
# hat food mat pat

# %% [markdown]
# ![Regex-Findall,%20Split,%20Sub.PNG](attachment:Regex-Findall,%20Split,%20Sub.PNG)

# %% [markdown]
# ![Supported%20Metacharacters-1.PNG](attachment:Supported%20Metacharacters-1.PNG)

# %% [markdown]
# ![Supported%20Metacharacters-2.PNG](attachment:Supported%20Metacharacters-2.PNG)

# %% [markdown]
# ![Repeated%20Characters.PNG](attachment:Repeated%20Characters.PNG)

# %%
# Quantifiers
# Note: It's very important to remember that the quantifier applies only to 
# the character immediately to the left. 
# Once or more: +
# Zero times or more: *
# Zero or once: ?
# matches any character: .
# Start of the string: ^
# End of the string: $
# Escape special characters: \
# a Character: |
# Set of characters: [ ]
# Set of characters: [ ]
### ^ transforms the expression to negative

# \S+ means “a string of non-whitespace characters” 
## \S is an example. It is very useful to use when you know a pattern doesn't contain spaces and 
## you have reached the end when you do find one.

# \s+ means “a string of whitespace characters”
# n times at least, m times at most {n, m}

# %% [markdown]
# ![Quantifiers.PNG](attachment:Quantifiers.PNG)

# %% [markdown]
# ![Subsitution%20&%20Safe%20Substitution.PNG](attachment:Subsitution%20&%20Safe%20Substitution.PNG)

# %%
# Two types of matching methods
# 1) Greedy
# 2) Non-greedy/Lazy

# Note: Standard quantifiers are greedy by default: * , + , ? , {num, num}
# Note: We can append a question mark(?) at the end of the greedy quantifiers 
# to convert them into lazy.

# %% [markdown]
# ![Special%20Characters.PNG](attachment:Special%20Characters.PNG)

# %% [markdown]
# ![Greedy%20vs%20Non-Greedy.PNG](attachment:Greedy%20vs%20Non-Greedy.PNG)
