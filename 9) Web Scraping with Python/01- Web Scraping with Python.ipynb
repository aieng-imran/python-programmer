# %% [markdown]
# # Web Scraping
#
# 1) HyperText Markup Language
#
# 2) Introduction to HTML Outro - HTML Tags and Attributes
#
# 3) XPath

# %% [markdown]
# ![Dream%20Pipe.PNG](attachment:Dream%20Pipe.PNG)

# %% [markdown]
# ![HTML%20Main%20Example.PNG](attachment:HTML%20Main%20Example.PNG)

# %% [markdown]
# ![HTML%20Tags.PNG](attachment:HTML%20Tags.PNG)

# %% [markdown]
# ![HTML%20Tree.PNG](attachment:HTML%20Tree.PNG)

# %% [markdown]
# ![HTML%20Tree%20example-1.PNG](attachment:HTML%20Tree%20example-1.PNG)

# %% [markdown]
# ![HTML%20Tree%20example-2.PNG](attachment:HTML%20Tree%20example-2.PNG)

# %% [markdown]
# ![Tag.PNG](attachment:Tag.PNG)

# %% [markdown]
# ![Div%20id.PNG](attachment:Div%20id.PNG)

# %% [markdown]
# ![href.PNG](attachment:href.PNG)

# %% [markdown]
# ![Xpath.PNG](attachment:Xpath.PNG)
