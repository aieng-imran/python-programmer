# %% [markdown]
# ![Course%20content-1.png](attachment:Course%20content-1.png)

# %% [markdown]
# ![Module%20package%20subpackage.PNG](attachment:Module%20package%20subpackage.PNG)

# %%
pip install mysklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# From script to package
# One common way to begin writing a package is to start with code you have 
# already written as a script.

# %%
# Generalizing functions that you already have is a common way of starting 
# a library. This means you can use the same code in other projects without 
# having to copy and paste it across.

# https://www.geeksforgeeks.org/text-analysis-in-python-3/

# %%
def count_words(filepath, words_list):

# Open the text file
    with open(filepath, encoding="UTF-8") as file:
        text = file.read()

    n = 0
    for word in text.split():
    # Count the number of times the words in the list appear
        if word.lower() in wordslist:
            n += 1

    print('Lewis Carroll uses the word "cat" {} times'.format(n))
    return n

# %%
# https://www.kaggle.com/datafiniti/hotel-reviews

# Now you have wrapped your word-counting function into a package, you can 
# reuse it easily in other projects.

from textanalysis.textanalysis import count_words

# Count the number of positive words
nb_positive_words = count_words('hotel-reviews.txt', ['good', 'great'])

# Count the number of negative words
nb_negative_words = count_words('hotel-reviews.csv', ['bad', 'awful'])

print("{} positive words.".format(nb_positive_words))
print("{} negative words.".format(nb_negative_words))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10096/2035348479.py in <module>
#       7
#       8 # Count the number of positive words
# ----> 9 nb_positive_words = count_words('hotel-reviews.txt', ['good', 'great'])
#      10
#      11 # Count the number of negative words
#
# E:\Google Drive\Important Documents\Educational Documents\Artificial Intelligence Venture\Python Programmer- Data Camp\Python Programmer\13) Developing Python Packages\textanalysis\textanalysis.py in count_words(filepath, words_list)
#       3 # Open the text file
#       4     with open(filepath) as file:
# ----> 5         text = file.read()
#       6
#       7     n = 0
#
# ~\anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ...

# %%
# Solved - UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d
# https://www.youtube.com/watch?v=yC2y4tOdF0g

# %%
# https://stackoverflow.com/questions/9233027/unicodedecodeerror-charmap-codec-cant-decode-byte-x-in-position-y-character

# %%
# https://realpython.com/documenting-python-code/#docstring-types
