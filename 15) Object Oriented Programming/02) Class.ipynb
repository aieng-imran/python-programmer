# %% [markdown]
# ### Python Objects and Classes

# %% [markdown]
# ![Python%20Objects%20&%20Classes.PNG](attachment:Python%20Objects%20&%20Classes.PNG)

# %% [markdown]
# ### Defining a Class

# %% [markdown]
# ![Defining%20a%20Class.PNG](attachment:Defining%20a%20Class.PNG)

# %%
class Person:
    "This is a person class"
    age = 10

    def greet(self):
        print('Hello')


# Output: 10
print(Person.age)

# Output: <function Person.greet>
print(Person.greet)

# Output: "This is a person class"
print(Person.__doc__)
# Out:
# 10
# <function Person.greet at 0x0000016E2A572550>
# This is a person class

# %% [markdown]
# ### Creating an Object in Python

# %% [markdown]
# ![Creating%20an%20Object.PNG](attachment:Creating%20an%20Object.PNG)

# %%
class Person:
    "This is a person class"
    age = 10

    def greet(self):
        print('Hello')


# create a new object of Person class
harry = Person()

# Output: <function Person.greet>
print(Person.greet)

# Output: <bound method Person.greet of <__main__.Person object>>
print(harry.greet)

# Calling object's greet() method
# Output: Hello
harry.greet()
# Out:
# <function Person.greet at 0x0000021BC396D4C0>
# <bound method Person.greet of <__main__.Person object at 0x0000021BC3955760>>
# Hello

# %% [markdown]
# ![Creating%20an%20Object-1.PNG](attachment:Creating%20an%20Object-1.PNG)

# %% [markdown]
# ### Constructors in Python

# %% [markdown]
# ![Constructor%20in%20Python.PNG](attachment:Constructor%20in%20Python.PNG)

# %% [markdown]
# ### Deleting Attributes and Objects

# %% [markdown]
# ![Deleting%20Attribute.PNG](attachment:Deleting%20Attribute.PNG)

# %% [markdown]
# ![Deleting%20objects.PNG](attachment:Deleting%20objects.PNG)
