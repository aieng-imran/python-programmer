# %% [markdown]
# # Inheritance

# %%
# https://www.programiz.com/python-programming/multiple-inheritance

# %% [markdown]
# ![Inheritance.PNG](attachment:Inheritance.PNG)

# %% [markdown]
# ![Inheritance%20Syntax.PNG](attachment:Inheritance%20Syntax.PNG)

# %% [markdown]
# ![Multilevel%20Inheritance.PNG](attachment:Multilevel%20Inheritance.PNG)

# %% [markdown]
# ![Multilevel%20Inheritance-3.PNG](attachment:Multilevel%20Inheritance-3.PNG)
