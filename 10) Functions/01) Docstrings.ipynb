# %% [markdown]
# ![Docstring.PNG](attachment:Docstring.PNG)

# %% [markdown]
# ![Docstring-%20Google%20Style.PNG](attachment:Docstring-%20Google%20Style.PNG)

# %% [markdown]
# ![Numpydoc.PNG](attachment:Numpydoc.PNG)

# %% [markdown]
# ![DRY.PNG](attachment:DRY.PNG)

# %%
# it is totally normal to copy and paste a bit of code, tweak it slightly, 
# and re-run it. However, this kind of repeated code can lead to real problems.

# But one of the problems with copying and pasting is that it is easy to 
# accidentally introduce errors that are hard to spot.

# %% [markdown]
# ![Use%20functions.PNG](attachment:Use%20functions.PNG)

# %% [markdown]
# ![One%20job%20per%20function.PNG](attachment:One%20job%20per%20function.PNG)

# %%
# Advantages of doing one thing
#The code becomes:

# 1) More flexible
# 2) More easily understood
# 3) Simpler to test
# 4) Simpler to debug
# 5) Easier to change

# %%
# Refactoring is the process of improving code by changing it a little bit 
# at a time.

# %% [markdown]
# ![Mutable%20default%20arguments.PNG](attachment:Mutable%20default%20arguments.PNG)
