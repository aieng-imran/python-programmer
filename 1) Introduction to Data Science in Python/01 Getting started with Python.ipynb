# %% [markdown]
# ## What will be covered
#
# 1) How to write and execute Python code with DataCamp
#
# 2) How to load data from a spreadsheet
#
# 3) How to turn data into beautiful plots

# %%
# Use an import statement to import seaborn with alias sns
import seaborn as sns

# %%
# Creating Variables

# Fill in Bayes' age (4.0)
bayes_age = 4.0

# Display the variable bayes_age
print(bayes_age)
# Out:
# 4.0

# %%
# Creating strings

# Bayes' favorite toy
favorite_toy = "Mr. Squeaky"

# Bayes' owner
owner = 'DataCamp'

# Display variables
print(favorite_toy)
print(owner)
# Out:
# Mr. Squeaky
# DataCamp

# %%
# Valid variable names
# Which of the following is not a valid variable name?
# 3dogs

# %% [markdown]
# # Fun with functions![Function-1.PNG](attachment:Function-1.PNG)

# %% [markdown]
# ![Function.PNG](attachment:Function.PNG)

# %%
# Functions perform actions:
# pd.read_csv() turns a csv file into a table in Python
# plt.plot() turns data into a line plot
# plt.show() displays plot in a new window

# %% [markdown]
# ![Keyword%20Argument.PNG](attachment:Keyword%20Argument.PNG)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Source of data: https://www.kaggle.com/timoboz/tesla-stock-data-from-2010-to-2020
TSLA_2010_20 = pd.read_csv('./data/TSLA_2010_20.csv')

# %%
print(sp500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-65765ca47f1b> in <module>
# ----> 1 print(sp500)
#
# NameError: name 'sp500' is not defined

# %%
# Plot a graph

x_values = TSLA_2010_20['Date']
y_values = TSLA_2010_20['Close']
plt.plot(x_values, y_values)
plt.xlabel = 'Date'
plt.ylabel = 'Close Price'

# Display the graph
plt.show()
