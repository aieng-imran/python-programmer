# %% [markdown]
# # Writing a Python Module
#
# 1) Writing Your First Package
#
# 2) Adding Functionality to Packages
#
# 3) Adding Functionality to Packages
#
# Note: The below-mentioned video is helpful
# # Python Package Tutorial - Organize Your Code
# # https://www.youtube.com/watch?v=qmsTqQbcBNM

# %% [markdown]
# ![Package%20Structure.PNG](attachment:Package%20Structure.PNG)

# %%
# How to Build Your Very First Python Package
# https://www.freecodecamp.org/news/build-your-first-python-package/

### Python Package Tutorial - Organize Your Code
# https://www.youtube.com/watch?v=qmsTqQbcBNM

# %% [markdown]
# # Adding Functionality to Packages

# %%
import numpy
#help(numpy)

# %%
import pycodestyle

# %%
pwd
# Out:
# 'E:\\Google Drive\\Important Documents\\Educational Documents\\Artificial Intelligence Venture\\Python Programmer- Data Camp\\Python Programmer\\12) Software Engineering for Data Scientist'
